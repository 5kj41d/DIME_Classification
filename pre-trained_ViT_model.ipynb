# %%
# https://pytorch.org/vision/main/models/vision_transformer.html
# https://huggingface.co/blog/fine-tune-vit
# https://huggingface.co/google/vit-base-patch16-224-in21k
# ViT model: https://github.com/pytorch/vision/blob/main/torchvision/models/vision_transformer.py#L37

# %%
# Load data from external source
import os
from torchvision.io import read_image
import matplotlib.pyplot as plt
import torchvision
import numpy as np
from PIL import Image

# Docs:
# https://pytorch.org/tutorials/beginner/basics/data_tutorial.html?highlight=dataloader

# 256x256 images

path_to_coins = r'C:\Users\Mate\Projects\Coin\data\coin_resized_224x224'
path_to_others = r'C:\Users\Mate\Projects\Coin\data\others_resized_224x224'

#path_to_coins = "/run/media/magnusjsc/T7/Classification-and-3D-reconstruction-of-archaeological-artifacts_DATA/coins-2023 224x224/coins"
#path_to_others = "/run/media/magnusjsc/T7/Classification-and-3D-reconstruction-of-archaeological-artifacts_DATA/other-2023 224x224/other"


# path_to_coins = "/mnt/c/Users/bucha/Pictures/coins_224x224"
# path_to_others = "/mnt/c/Users/bucha/Pictures/other_224x224"


def load_data_from_directory_with_limit(directory_path, label, limit=10000):
    data = []
    labels = []
    count = 0

    for filename in os.listdir(directory_path):
        if filename.endswith(".jpg"): 
            image_path = os.path.join(directory_path, filename)
            image = read_image(image_path)

            # Check if the image is RGB
            if image.shape[0] == 3:
                data.append(image)
                labels.append(label)
                count += 1

            if count >= limit:
                break

    return data, labels # Tuple

# Load data call
data_coins, labels_coins = load_data_from_directory_with_limit(path_to_coins, label=1, limit=5000)
data_others, labels_others = load_data_from_directory_with_limit(path_to_others, label=0, limit=5000)

print(f'Size of data_coins {len(data_coins)} : Size of labels_coins {len(labels_coins)}')
print(f'Size of data_others {len(data_others)} : Size of labels_others {len(labels_others)}')

def imshow_grid(images, num_images = 30):
    grid = torchvision.utils.make_grid(images[:num_images], nrow = 10)
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    plt.title('Sample Images')
    plt.axis('on')
    plt.show()

num_images_to_display_per_category = 15
data_to_display = data_coins[:num_images_to_display_per_category] + data_others[:num_images_to_display_per_category]
imshow_grid(data_to_display, num_images=num_images_to_display_per_category * 2)
# Out:
# Size of data_coins 5000 : Size of labels_coins 5000
# Size of data_others 5000 : Size of labels_others 5000

# %%
import os
from torch.utils.data import Dataset, DataLoader, ConcatDataset, random_split
from torchvision import transforms
from torchvision.io import read_image
import torch
import torchvision
from torch.utils.data import random_split
import matplotlib.pyplot as plt
import numpy as np

class customDataset(Dataset):
    def __init__(self, tensors, transform=None):
        # Check the sizes of data and labels match
        assert all(tensors[0].size(0)==t.size(0) for t in tensors), "Size mismatch between tensors"

        # Assign input
        self.tensors = tensors
        self.transform = transform

    # What to do when we want an item from the dataset
    def __getitem__(self, index):
        # Return the transformed version of x if there are transforms
        if self.transform:
            x = self.transform(self.tensors[0][index])
        else: 
            x = self.tensors[0][index]

        # And return the label too
        y = self.tensors[1][index].view(1) # Convert y to a single-element tensor

        return x,y # Return the data as a tuple (data,label)

    def __len__(self):
        return self.tensors[0].size(0)


# Create a list of  transforms
imgTrans = transforms.Compose(
    [
        transforms.ToPILImage(), # PIL = library for images - Works for several transformations. To PIL image type
        transforms.RandomVerticalFlip(p=.5),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor() # Transform the image to PyTorch tensor and normalizes the data [0;1] - Last 
    ]
)

# To Torch tensors
coin_dataT = torch.stack(data_coins)
coin_labelsT = torch.tensor(labels_coins)
other_dataT = torch.stack(data_others)
other_labelsT = torch.tensor(labels_others)

# For the Coin dataset
coin_data_transformed_defined = customDataset(tensors=(coin_dataT, coin_labelsT), transform=imgTrans)
# For the Other dataset
other_data_transformed_defined = customDataset(tensors=(other_dataT, other_labelsT), transform=imgTrans)
# Combine these two above datasets
combined_dataset_transformed_defined = ConcatDataset([coin_data_transformed_defined, other_data_transformed_defined])

# Split the data for training, validation, and testing
training = 0.7
validation = 0.15
testing = 0.15

total_size = len(combined_dataset_transformed_defined)
train_size = int(training * total_size)
val_size = int(validation * total_size)
test_size = total_size - train_size - val_size

# Randomly split the full dataset into training, validation and testing sets
train_set, val_set, test_set = random_split(combined_dataset_transformed_defined, [train_size, val_size, test_size])

# Hyperparameter - Batch size - GPU may be overloaded with memory allocations if too high
BATCH_SIZE = 10
# Create data loaders for each set
coin_loader = DataLoader(coin_data_transformed_defined, batch_size=BATCH_SIZE, shuffle=False) # For test -> below cell
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True) # Shuffle the training set
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

print(f'Total number of elements in train_loader: {len(train_loader) * BATCH_SIZE} : Each batch size {len(train_loader)}')
print(f'Total number of elements in val_loader: {len(val_loader) * BATCH_SIZE} : Each batch size {len(val_loader)}')
print(f'Total number of elements in test_loader: {len(test_loader) * BATCH_SIZE} : Each batch size {len(test_loader)}')
# Out:
# Total number of elements in train_loader: 7000 : Each batch size 700
# Total number of elements in val_loader: 1500 : Each batch size 150
# Total number of elements in test_loader: 1500 : Each batch size 150

# %%
from transformers import ViTFeatureExtractor, ViTForImageClassification, AdamW
import torch
from torchinfo import summary

model_name_or_path = 'google/vit-base-patch16-224-in21k'
vit_model = ViTForImageClassification.from_pretrained(model_name_or_path)
vit_model.size = {"height": 256, "width": 256}

# Model configs
print(vit_model)

# Move the model to the desired device (cuda or cpu)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vit_model.to(device)

# Input size (batch_size, channels, height, width)
input_size = (10, 3, 224, 224)

# Print the summary
summary(
    model = vit_model, 
    input_size = input_size, 
    device = device.type,
    verbose = 1,  # 2 for full info
    col_names = [
        "input_size", 
        "num_params", 
        "output_size", 
        "mult_adds", 
        "trainable"
    ],
    mode = "train"
)
# Out:
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# c:\Users\Mate\Projects\Coin\coinvenv\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Mate\.cache\huggingface\hub\models--google--vit-base-patch16-224-in21k. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/346M [00:00<?, ?B/s]
# c:\Users\Mate\Projects\Coin\coinvenv\lib\site-packages\torch\_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ViTForImageClassification(
#   (vit): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): ViTPatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ViTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )
# ====================================================================================================================================================================================
# Layer (type:depth-idx)                                  Input Shape               Param #                   Output Shape              Mult-Adds                 Trainable
# ====================================================================================================================================================================================
# ViTForImageClassification                               [10, 3, 224, 224]         --                        [10, 2]                   --                        True
# ├─ViTModel: 1-1                                         [10, 3, 224, 224]         --                        [10, 197, 768]            --                        True
# │    └─ViTEmbeddings: 2-1                               [10, 3, 224, 224]         152,064                   [10, 197, 768]            --                        True
# │    │    └─ViTPatchEmbeddings: 3-1                     [10, 3, 224, 224]         590,592                   [10, 196, 768]            1,157,560,320             True
# │    │    └─Dropout: 3-2                                [10, 197, 768]            --                        [10, 197, 768]            --                        --
# │    └─ViTEncoder: 2-2                                  [10, 197, 768]            --                        [10, 197, 768]            --                        True
# │    │    └─ModuleList: 3-3                             --                        85,054,464                --                        --                        True
# │    └─LayerNorm: 2-3                                   [10, 197, 768]            1,536                     [10, 197, 768]            15,360                    True
# ├─Linear: 1-2                                           [10, 768]                 1,538                     [10, 2]                   15,380                    True
# ====================================================================================================================================================================================
# Total params: 85,800,194
# Trainable params: 85,800,194
# Non-trainable params: 0
# Total mult-adds (G): 2.01
# ====================================================================================================================================================================================
# Input size (MB): 6.02
# Forward/backward pass size (MB): 1621.83
# Params size (MB): 342.59
# Estimated Total Size (MB): 1970.45
# ====================================================================================================================================================================================
# ====================================================================================================================================================================================
# Layer (type:depth-idx)                                  Input Shape               Param #                   Output Shape              Mult-Adds                 Trainable
# ====================================================================================================================================================================================
# ViTForImageClassification                               [10, 3, 224, 224]         --                        [10, 2]                   --                        True
# ├─ViTModel: 1-1                                         [10, 3, 224, 224]         --                        [10, 197, 768]            --                        True
# │    └─ViTEmbeddings: 2-1                               [10, 3, 224, 224]         152,064                   [10, 197, 768]            --                        True
# │    │    └─ViTPatchEmbeddings: 3-1                     [10, 3, 224, 224]         590,592                   [10, 196, 768]            1,157,560,320             True
# │    │    └─Dropout: 3-2                                [10, 197, 768]            --                        [10, 197, 768]            --                        --
# │    └─ViTEncoder: 2-2                                  [10, 197, 768]            --                        [10, 197, 768]            --                        True
# │    │    └─ModuleList: 3-3                             --                        85,054,464                --                        --                        True
# │    └─LayerNorm: 2-3                                   [10, 197, 768]            1,536                     [10, 197, 768]            15,360                    True
# ├─Linear: 1-2                                           [10, 768]                 1,538                     [10, 2]                   15,380                    True
# ====================================================================================================================================================================================
# Total params: 85,800,194
# Trainable params: 85,800,194
# Non-trainable params: 0
# Total mult-adds (G): 2.01
# ====================================================================================================================================================================================
# Input size (MB): 6.02
# Forward/backward pass size (MB): 1621.83
# Params size (MB): 342.59
# Estimated Total Size (MB): 1970.45
# ====================================================================================================================================================================================

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, confusion_matrix
import time 
import seaborn as sns
import numpy as np

optimizer = torch.optim.AdamW(vit_model.parameters(), lr = 1e-5)
criterion = torch.nn.BCEWithLogitsLoss()
threshold = 0.5

num_epochs = 250
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

vit_model.to(device)

train_losses = []

all_val_preds = []
all_val_labels = []

test_losses = []
test_accuracies = []
test_precisions = []
test_recalls = []
test_f1_scores = []
test_auc_rocs = []
test_conf_matrices = []

test_loss = 0
test_accuracy = 0
test_precision = 0
test_recall = 0
test_f1 = 0
test_roc_auc = 0
test_conf_matrices = []

def get_prediction(predictions):
    largest_values = []
    sigmoid_values = []

    for preds in predictions:
        # Get the largest values in prediction
        largest_values.append(torch.max(preds))

    for values in largest_values:
        # Applying sigmoid to the largest value
        sigmoid_values.append(torch.sigmoid(values))

    # Convert sigmoid_values to a tensor
    sigmoid_tensor = torch.stack(sigmoid_values)
    sigmoid_tensor = sigmoid_tensor.view(-1, 1) # Reshape tensor to fit the labels tensor

    return sigmoid_tensor    
    
# RUN
total_time_start = time.time()  # Record the start time
for epoch in range(num_epochs):
    epoch_time_start = time.time() # Timer
    # Testing part 
    vit_model.train()
    total_train_loss = 0.0
    for batch in train_loader:
        inputs, labels = batch
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = vit_model(inputs)
        prediction = get_prediction(outputs.logits)
        loss = criterion(prediction, labels.float())
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()

    # Calculate average training loss for the epoch
    avg_train_loss = total_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    
    # Validation part 
    vit_model.eval()

    total_val_loss = 0.0
    with torch.no_grad():
        for batch in val_loader:
            inputs, labels = batch
            inputs, labels = inputs.to(device), labels.to(device)
     
            outputs = vit_model(inputs)
            prediction = get_prediction(outputs.logits) 
            val_loss = criterion(prediction, labels.float())
            total_val_loss += val_loss.item()

    # Testing part 
    all_test_preds = []  # Reset predictions for each epoch
    all_test_labels = []  # Reset labels for each epoch
    total_test_loss = 0.0
    with torch.no_grad():
        for batch in test_loader:
            inputs, labels = batch
            inputs, labels = inputs.to(device), labels.to(device) # CPU or GPU
     
            outputs = vit_model(inputs)
            prediction = get_prediction(outputs.logits) 
            test_loss = criterion(prediction, labels.float())
            total_test_loss += test_loss.item()

            preds = (prediction > threshold).int()  # Threshold is used to determine the predicted value - 0 or 1 based on the threshold value
            all_test_preds.extend(preds.cpu().numpy())
            all_test_labels.extend(labels.cpu().numpy())
        
        # https://scikit-learn.org/stable/modules/model_evaluation.html
        test_loss = total_test_loss / len(test_loader)
        test_accuracy = accuracy_score(
            all_test_labels,
            all_test_preds
        )
        test_precision = precision_score(
            all_test_labels,
            all_test_preds,
            zero_division = 0,
            average='binary'
        )
        test_recall = recall_score(
            all_test_labels,
            all_test_preds
        )
        test_f1 = f1_score(
            all_test_labels,
            all_test_preds
        )
    
        # Calculate AUC-ROC
        fpr, tpr, _ = roc_curve(all_test_labels, all_test_preds)
        test_roc_auc = auc(fpr, tpr)
        # Create confusion matrix
        test_conf_matrix = confusion_matrix(all_test_labels, all_test_preds)

        # Calculate and print the time taken for the epoch
        epoch_time_end = time.time()
        epoch_time_elapsed = epoch_time_end - epoch_time_start
        
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        test_precisions.append(test_precision)
        test_recalls.append(test_recall)
        test_f1_scores.append(test_f1)
        test_auc_rocs.append(test_roc_auc)
        test_conf_matrices.append(test_conf_matrix)


        # Testing prints
        print(f'Epoch {epoch + 1}/{num_epochs} - Time: {epoch_time_elapsed:.4f}s - '
              f'Training loss: {avg_train_loss:.8f} - '
              f'Test Loss: {test_loss:.8f} - '
              f'Test Accuracy: {test_accuracy:.8f} - '
              f'Test Precision: {test_precision:.8f} - '
              f'Test Recall: {test_recall:.8f} - '
              f'Test F1 Score: {test_f1:.8f}') 


            
# Calculate and print the total time taken in total for all epochs
total_time_end = time.time()
total_time_elapsed = total_time_end - total_time_start
print(f'Total Training Time: {total_time_elapsed:.4f}s')        
    
# Plotting
epochs = np.arange(1, num_epochs + 1)
plt.figure(figsize=(10, 15))  # Adjust the figure size accordingly

# Plot Training Loss
plt.subplot(4, 1, 1)  # Five rows, one column, third subplot
plt.plot(epochs, train_losses, label='Training Loss', linestyle='dashed', color='orange')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy, Precision, Recall, F1 Score, and AUC-ROC for Test
plt.subplot(4, 1, 2)  # Five rows, one column, third subplot
plt.plot(epochs, test_accuracies, label='Test Accuracy')
plt.plot(epochs, test_precisions, label='Test Precision')
plt.plot(epochs, test_recalls, label='Test Recall')
plt.plot(epochs, test_f1_scores, label='Test F1 Score')
plt.plot(epochs, test_auc_rocs, label='Test AUC-ROC')
plt.title('Test Metrics')
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.legend()

# Plot Testing Loss
plt.subplot(4, 1, 3)  # Five rows, one column, fourth subplot
plt.plot(epochs, test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Confusion Matrices for each epoch
plt.subplot(4, 1, 4)  # Five rows, one column, fifth subplot
all_conf_matrices = np.stack(test_conf_matrices, axis=0)
avg_conf_matrix = np.mean(all_conf_matrices, axis=0)  # Calculate the average confusion matrix
sns.heatmap(avg_conf_matrix, annot=True, fmt='.2f', cmap='Blues', cbar=False)
plt.title('Average Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/250 - Time: 132.2494s - Training loss: 0.53918686 - Test Loss: 0.55366786 - Test Accuracy: 0.89866667 - Test Precision: 0.90013141 - Test Recall: 0.90013141 - Test F1 Score: 0.90013141
# Epoch 2/250 - Time: 131.9008s - Training loss: 0.53318067 - Test Loss: 0.54993342 - Test Accuracy: 0.90933333 - Test Precision: 0.89607098 - Test Recall: 0.92904074 - Test F1 Score: 0.91225806
# Epoch 3/250 - Time: 128.9780s - Training loss: 0.53051421 - Test Loss: 0.54871918 - Test Accuracy: 0.90400000 - Test Precision: 0.90969456 - Test Recall: 0.90013141 - Test F1 Score: 0.90488771
# Epoch 4/250 - Time: 127.3964s - Training loss: 0.53037014 - Test Loss: 0.54912746 - Test Accuracy: 0.89200000 - Test Precision: 0.93468795 - Test Recall: 0.84625493 - Test F1 Score: 0.88827586
# Epoch 5/250 - Time: 127.3994s - Training loss: 0.53015655 - Test Loss: 0.55176291 - Test Accuracy: 0.89666667 - Test Precision: 0.90185676 - Test Recall: 0.89356110 - Test F1 Score: 0.89768977
# Epoch 6/250 - Time: 127.3836s - Training loss: 0.52539177 - Test Loss: 0.54408585 - Test Accuracy: 0.90666667 - Test Precision: 0.93426573 - Test Recall: 0.87779238 - Test F1 Score: 0.90514905
# Epoch 7/250 - Time: 127.4234s - Training loss: 0.52693174 - Test Loss: 0.54698833 - Test Accuracy: 0.90866667 - Test Precision: 0.90731070 - Test Recall: 0.91327201 - Test F1 Score: 0.91028160
# Epoch 8/250 - Time: 127.3508s - Training loss: 0.52235998 - Test Loss: 0.54832651 - Test Accuracy: 0.90933333 - Test Precision: 0.89407314 - Test Recall: 0.93166886 - Test F1 Score: 0.91248391
# Epoch 9/250 - Time: 126.5836s - Training loss: 0.52182743 - Test Loss: 0.55539501 - Test Accuracy: 0.90200000 - Test Precision: 0.86899038 - Test Recall: 0.95006570 - Test F1 Score: 0.90772128
# Epoch 10/250 - Time: 126.2371s - Training loss: 0.52144869 - Test Loss: 0.54612320 - Test Accuracy: 0.90666667 - Test Precision: 0.91344874 - Test Recall: 0.90144547 - Test F1 Score: 0.90740741
# Epoch 11/250 - Time: 126.1872s - Training loss: 0.52145073 - Test Loss: 0.54841245 - Test Accuracy: 0.89866667 - Test Precision: 0.92116183 - Test Recall: 0.87516426 - Test F1 Score: 0.89757412
# Epoch 12/250 - Time: 126.1960s - Training loss: 0.52094378 - Test Loss: 0.54305108 - Test Accuracy: 0.91400000 - Test Precision: 0.92245989 - Test Recall: 0.90670171 - Test F1 Score: 0.91451292
# Epoch 13/250 - Time: 126.2947s - Training loss: 0.52081544 - Test Loss: 0.54140618 - Test Accuracy: 0.91866667 - Test Precision: 0.92317881 - Test Recall: 0.91590013 - Test F1 Score: 0.91952507
# Epoch 14/250 - Time: 126.1653s - Training loss: 0.52083478 - Test Loss: 0.54415836 - Test Accuracy: 0.90400000 - Test Precision: 0.93758865 - Test Recall: 0.86859396 - Test F1 Score: 0.90177353
# Epoch 15/250 - Time: 126.1634s - Training loss: 0.51870244 - Test Loss: 0.54685775 - Test Accuracy: 0.91200000 - Test Precision: 0.89961881 - Test Recall: 0.93035480 - Test F1 Score: 0.91472868
# Epoch 16/250 - Time: 126.1994s - Training loss: 0.51774918 - Test Loss: 0.54102989 - Test Accuracy: 0.91000000 - Test Precision: 0.94460227 - Test Recall: 0.87385020 - Test F1 Score: 0.90784983
# Epoch 17/250 - Time: 126.1244s - Training loss: 0.51990290 - Test Loss: 0.54069966 - Test Accuracy: 0.92000000 - Test Precision: 0.92226614 - Test Recall: 0.91984231 - Test F1 Score: 0.92105263
# Epoch 18/250 - Time: 126.4291s - Training loss: 0.51595390 - Test Loss: 0.54038744 - Test Accuracy: 0.91933333 - Test Precision: 0.91666667 - Test Recall: 0.92509855 - Test F1 Score: 0.92086331
# Epoch 19/250 - Time: 126.4261s - Training loss: 0.51578385 - Test Loss: 0.54432737 - Test Accuracy: 0.91000000 - Test Precision: 0.91622340 - Test Recall: 0.90538765 - Test F1 Score: 0.91077330
# Epoch 20/250 - Time: 126.2082s - Training loss: 0.51513730 - Test Loss: 0.54872108 - Test Accuracy: 0.88333333 - Test Precision: 0.95496894 - Test Recall: 0.80814717 - Test F1 Score: 0.87544484
# Epoch 21/250 - Time: 126.3006s - Training loss: 0.51828082 - Test Loss: 0.54148384 - Test Accuracy: 0.91600000 - Test Precision: 0.92052980 - Test Recall: 0.91327201 - Test F1 Score: 0.91688654
# Epoch 22/250 - Time: 126.2512s - Training loss: 0.51526947 - Test Loss: 0.53959786 - Test Accuracy: 0.91666667 - Test Precision: 0.93561644 - Test Recall: 0.89750329 - Test F1 Score: 0.91616365
# Epoch 23/250 - Time: 126.2423s - Training loss: 0.51497510 - Test Loss: 0.54692555 - Test Accuracy: 0.91000000 - Test Precision: 0.89923469 - Test Recall: 0.92641261 - Test F1 Score: 0.91262136
# Epoch 24/250 - Time: 126.2169s - Training loss: 0.51379954 - Test Loss: 0.54146333 - Test Accuracy: 0.91266667 - Test Precision: 0.92915531 - Test Recall: 0.89618922 - Test F1 Score: 0.91237458
# Epoch 25/250 - Time: 126.2665s - Training loss: 0.51517713 - Test Loss: 0.54748322 - Test Accuracy: 0.90600000 - Test Precision: 0.90789474 - Test Recall: 0.90670171 - Test F1 Score: 0.90729783
# Epoch 26/250 - Time: 126.2397s - Training loss: 0.51419273 - Test Loss: 0.54489021 - Test Accuracy: 0.91533333 - Test Precision: 0.90228426 - Test Recall: 0.93429698 - Test F1 Score: 0.91801162
# Epoch 27/250 - Time: 126.2755s - Training loss: 0.51538081 - Test Loss: 0.53986383 - Test Accuracy: 0.92066667 - Test Precision: 0.92236842 - Test Recall: 0.92115637 - Test F1 Score: 0.92176200
# Epoch 28/250 - Time: 126.2933s - Training loss: 0.51325349 - Test Loss: 0.54687585 - Test Accuracy: 0.89933333 - Test Precision: 0.93571429 - Test Recall: 0.86070959 - Test F1 Score: 0.89664613
# Epoch 29/250 - Time: 126.2498s - Training loss: 0.51567046 - Test Loss: 0.55356515 - Test Accuracy: 0.90466667 - Test Precision: 0.86873508 - Test Recall: 0.95663601 - Test F1 Score: 0.91056911
# Epoch 30/250 - Time: 126.1614s - Training loss: 0.51266556 - Test Loss: 0.54620895 - Test Accuracy: 0.90200000 - Test Precision: 0.92170330 - Test Recall: 0.88173456 - Test F1 Score: 0.90127602
# Epoch 31/250 - Time: 126.2842s - Training loss: 0.51313509 - Test Loss: 0.54664631 - Test Accuracy: 0.91066667 - Test Precision: 0.89834816 - Test Recall: 0.92904074 - Test F1 Score: 0.91343669
# Epoch 32/250 - Time: 126.2899s - Training loss: 0.51372925 - Test Loss: 0.54703764 - Test Accuracy: 0.91333333 - Test Precision: 0.89192547 - Test Recall: 0.94349540 - Test F1 Score: 0.91698595
# Epoch 33/250 - Time: 126.2222s - Training loss: 0.51205059 - Test Loss: 0.54786957 - Test Accuracy: 0.91133333 - Test Precision: 0.89152120 - Test Recall: 0.93955322 - Test F1 Score: 0.91490723
# Epoch 34/250 - Time: 126.3137s - Training loss: 0.51188756 - Test Loss: 0.55229569 - Test Accuracy: 0.90600000 - Test Precision: 0.87621359 - Test Recall: 0.94875164 - Test F1 Score: 0.91104101
# Epoch 35/250 - Time: 126.2058s - Training loss: 0.51250994 - Test Loss: 0.54315848 - Test Accuracy: 0.91866667 - Test Precision: 0.90909091 - Test Recall: 0.93298292 - Test F1 Score: 0.92088197
# Epoch 36/250 - Time: 126.2308s - Training loss: 0.51045859 - Test Loss: 0.54253817 - Test Accuracy: 0.91933333 - Test Precision: 0.91025641 - Test Recall: 0.93298292 - Test F1 Score: 0.92147956
# Epoch 37/250 - Time: 126.2015s - Training loss: 0.51127701 - Test Loss: 0.55114123 - Test Accuracy: 0.88533333 - Test Precision: 0.93118594 - Test Recall: 0.83574244 - Test F1 Score: 0.88088643
# Epoch 38/250 - Time: 126.2961s - Training loss: 0.51703496 - Test Loss: 0.55976811 - Test Accuracy: 0.86400000 - Test Precision: 0.92780338 - Test Recall: 0.79369251 - Test F1 Score: 0.85552408
# Epoch 39/250 - Time: 126.2358s - Training loss: 0.51461683 - Test Loss: 0.54275759 - Test Accuracy: 0.91733333 - Test Precision: 0.91096774 - Test Recall: 0.92772668 - Test F1 Score: 0.91927083
# Epoch 40/250 - Time: 126.2592s - Training loss: 0.51191619 - Test Loss: 0.54338984 - Test Accuracy: 0.91400000 - Test Precision: 0.91253264 - Test Recall: 0.91852825 - Test F1 Score: 0.91552063
# Epoch 41/250 - Time: 126.2928s - Training loss: 0.51110199 - Test Loss: 0.54925956 - Test Accuracy: 0.90533333 - Test Precision: 0.89426752 - Test Recall: 0.92247043 - Test F1 Score: 0.90815006
# Epoch 42/250 - Time: 126.1402s - Training loss: 0.51141425 - Test Loss: 0.54465812 - Test Accuracy: 0.91000000 - Test Precision: 0.91622340 - Test Recall: 0.90538765 - Test F1 Score: 0.91077330
# Epoch 43/250 - Time: 126.2385s - Training loss: 0.51241433 - Test Loss: 0.54523748 - Test Accuracy: 0.90066667 - Test Precision: 0.93342776 - Test Recall: 0.86596583 - Test F1 Score: 0.89843217
# Epoch 44/250 - Time: 126.2989s - Training loss: 0.51325717 - Test Loss: 0.54200276 - Test Accuracy: 0.91200000 - Test Precision: 0.93379310 - Test Recall: 0.88961892 - Test F1 Score: 0.91117093
# Epoch 45/250 - Time: 126.2740s - Training loss: 0.50968661 - Test Loss: 0.54532502 - Test Accuracy: 0.90333333 - Test Precision: 0.92896936 - Test Recall: 0.87647832 - Test F1 Score: 0.90196078
# Epoch 46/250 - Time: 126.2996s - Training loss: 0.51196355 - Test Loss: 0.54045720 - Test Accuracy: 0.92000000 - Test Precision: 0.92226614 - Test Recall: 0.91984231 - Test F1 Score: 0.92105263
# Epoch 47/250 - Time: 126.3613s - Training loss: 0.51226946 - Test Loss: 0.54858074 - Test Accuracy: 0.91000000 - Test Precision: 0.89027431 - Test Recall: 0.93823916 - Test F1 Score: 0.91362764
# Epoch 48/250 - Time: 126.2146s - Training loss: 0.51248285 - Test Loss: 0.54813965 - Test Accuracy: 0.90866667 - Test Precision: 0.89694656 - Test Recall: 0.92641261 - Test F1 Score: 0.91144150
# Epoch 49/250 - Time: 126.2732s - Training loss: 0.51002017 - Test Loss: 0.54421614 - Test Accuracy: 0.91133333 - Test Precision: 0.90992167 - Test Recall: 0.91590013 - Test F1 Score: 0.91290111
# Epoch 50/250 - Time: 126.2368s - Training loss: 0.51097936 - Test Loss: 0.54339915 - Test Accuracy: 0.91800000 - Test Precision: 0.90585242 - Test Recall: 0.93561104 - Test F1 Score: 0.92049127
# Epoch 51/250 - Time: 126.2147s - Training loss: 0.51251825 - Test Loss: 0.54148384 - Test Accuracy: 0.91466667 - Test Precision: 0.92712551 - Test Recall: 0.90275953 - Test F1 Score: 0.91478029
# Epoch 52/250 - Time: 126.2971s - Training loss: 0.51203888 - Test Loss: 0.55391511 - Test Accuracy: 0.90400000 - Test Precision: 0.86769964 - Test Recall: 0.95663601 - Test F1 Score: 0.91000000
# Epoch 53/250 - Time: 126.2691s - Training loss: 0.51182596 - Test Loss: 0.55260037 - Test Accuracy: 0.90600000 - Test Precision: 0.87621359 - Test Recall: 0.94875164 - Test F1 Score: 0.91104101
# Epoch 54/250 - Time: 126.2565s - Training loss: 0.51151984 - Test Loss: 0.54457165 - Test Accuracy: 0.90866667 - Test Precision: 0.91823056 - Test Recall: 0.90013141 - Test F1 Score: 0.90909091
# Epoch 55/250 - Time: 126.6047s - Training loss: 0.50955007 - Test Loss: 0.54068107 - Test Accuracy: 0.92200000 - Test Precision: 0.91282051 - Test Recall: 0.93561104 - Test F1 Score: 0.92407528
# Epoch 56/250 - Time: 126.2976s - Training loss: 0.51017790 - Test Loss: 0.53801878 - Test Accuracy: 0.92266667 - Test Precision: 0.92715232 - Test Recall: 0.91984231 - Test F1 Score: 0.92348285
# Epoch 57/250 - Time: 126.3415s - Training loss: 0.51080915 - Test Loss: 0.55488391 - Test Accuracy: 0.89733333 - Test Precision: 0.88080301 - Test Recall: 0.92247043 - Test F1 Score: 0.90115533
# Epoch 58/250 - Time: 126.1546s - Training loss: 0.51326051 - Test Loss: 0.54838162 - Test Accuracy: 0.91200000 - Test Precision: 0.89068323 - Test Recall: 0.94218134 - Test F1 Score: 0.91570881
# Epoch 59/250 - Time: 126.1810s - Training loss: 0.51009318 - Test Loss: 0.54408539 - Test Accuracy: 0.91600000 - Test Precision: 0.90445860 - Test Recall: 0.93298292 - Test F1 Score: 0.91849935
# Epoch 60/250 - Time: 126.2686s - Training loss: 0.51164447 - Test Loss: 0.54415006 - Test Accuracy: 0.91733333 - Test Precision: 0.90367554 - Test Recall: 0.93692510 - Test F1 Score: 0.92000000
# Epoch 61/250 - Time: 126.2440s - Training loss: 0.51101699 - Test Loss: 0.54142164 - Test Accuracy: 0.92266667 - Test Precision: 0.91293214 - Test Recall: 0.93692510 - Test F1 Score: 0.92477302
# Epoch 62/250 - Time: 126.1326s - Training loss: 0.51180783 - Test Loss: 0.54616220 - Test Accuracy: 0.91133333 - Test Precision: 0.90153453 - Test Recall: 0.92641261 - Test F1 Score: 0.91380428
# Epoch 63/250 - Time: 126.1584s - Training loss: 0.51105079 - Test Loss: 0.54047622 - Test Accuracy: 0.92200000 - Test Precision: 0.91494845 - Test Recall: 0.93298292 - Test F1 Score: 0.92387768
# Epoch 64/250 - Time: 126.1544s - Training loss: 0.51030385 - Test Loss: 0.55279663 - Test Accuracy: 0.90066667 - Test Precision: 0.88345865 - Test Recall: 0.92641261 - Test F1 Score: 0.90442591
# Epoch 65/250 - Time: 126.1887s - Training loss: 0.51217993 - Test Loss: 0.55053130 - Test Accuracy: 0.88933333 - Test Precision: 0.92682927 - Test Recall: 0.84888305 - Test F1 Score: 0.88614540
# Epoch 66/250 - Time: 126.1552s - Training loss: 0.51192558 - Test Loss: 0.54415441 - Test Accuracy: 0.91466667 - Test Precision: 0.90629012 - Test Recall: 0.92772668 - Test F1 Score: 0.91688312
# Epoch 67/250 - Time: 126.1047s - Training loss: 0.51029674 - Test Loss: 0.53895576 - Test Accuracy: 0.91866667 - Test Precision: 0.93351425 - Test Recall: 0.90407359 - Test F1 Score: 0.91855808
# Epoch 68/250 - Time: 126.0889s - Training loss: 0.51396159 - Test Loss: 0.53881729 - Test Accuracy: 0.92000000 - Test Precision: 0.93252362 - Test Recall: 0.90801577 - Test F1 Score: 0.92010652
# Epoch 69/250 - Time: 126.2238s - Training loss: 0.50952706 - Test Loss: 0.54377685 - Test Accuracy: 0.91133333 - Test Precision: 0.91866667 - Test Recall: 0.90538765 - Test F1 Score: 0.91197882
# Epoch 70/250 - Time: 126.2909s - Training loss: 0.50957919 - Test Loss: 0.54553035 - Test Accuracy: 0.91866667 - Test Precision: 0.89395808 - Test Recall: 0.95269382 - Test F1 Score: 0.92239186
# Epoch 71/250 - Time: 126.3794s - Training loss: 0.51005246 - Test Loss: 0.54650241 - Test Accuracy: 0.90666667 - Test Precision: 0.91017173 - Test Recall: 0.90538765 - Test F1 Score: 0.90777339
# Epoch 72/250 - Time: 126.2428s - Training loss: 0.50957880 - Test Loss: 0.54178286 - Test Accuracy: 0.91933333 - Test Precision: 0.91666667 - Test Recall: 0.92509855 - Test F1 Score: 0.92086331
# Epoch 73/250 - Time: 126.1407s - Training loss: 0.50988209 - Test Loss: 0.54292965 - Test Accuracy: 0.91666667 - Test Precision: 0.90874036 - Test Recall: 0.92904074 - Test F1 Score: 0.91877843
# Epoch 74/250 - Time: 126.3029s - Training loss: 0.51343781 - Test Loss: 0.54343331 - Test Accuracy: 0.91400000 - Test Precision: 0.91145833 - Test Recall: 0.91984231 - Test F1 Score: 0.91563113
# Epoch 75/250 - Time: 126.2841s - Training loss: 0.50943397 - Test Loss: 0.54414913 - Test Accuracy: 0.91666667 - Test Precision: 0.90561224 - Test Recall: 0.93298292 - Test F1 Score: 0.91909385
# Epoch 76/250 - Time: 126.2422s - Training loss: 0.51270995 - Test Loss: 0.55075229 - Test Accuracy: 0.90933333 - Test Precision: 0.87878788 - Test Recall: 0.95269382 - Test F1 Score: 0.91424968
# Epoch 77/250 - Time: 126.2450s - Training loss: 0.51100351 - Test Loss: 0.54522764 - Test Accuracy: 0.90400000 - Test Precision: 0.92906815 - Test Recall: 0.87779238 - Test F1 Score: 0.90270270
# Epoch 78/250 - Time: 126.1732s - Training loss: 0.50919996 - Test Loss: 0.54684034 - Test Accuracy: 0.90800000 - Test Precision: 0.90825688 - Test Recall: 0.91064389 - Test F1 Score: 0.90944882
# Epoch 79/250 - Time: 126.2095s - Training loss: 0.50906642 - Test Loss: 0.54641921 - Test Accuracy: 0.90200000 - Test Precision: 0.92170330 - Test Recall: 0.88173456 - Test F1 Score: 0.90127602
# Epoch 80/250 - Time: 126.2222s - Training loss: 0.51050497 - Test Loss: 0.54722637 - Test Accuracy: 0.90933333 - Test Precision: 0.89707751 - Test Recall: 0.92772668 - Test F1 Score: 0.91214470
# Epoch 81/250 - Time: 126.7671s - Training loss: 0.51012235 - Test Loss: 0.54228031 - Test Accuracy: 0.91933333 - Test Precision: 0.91237113 - Test Recall: 0.93035480 - Test F1 Score: 0.92127521
# Epoch 82/250 - Time: 130.4478s - Training loss: 0.50828375 - Test Loss: 0.54504813 - Test Accuracy: 0.91466667 - Test Precision: 0.90421456 - Test Recall: 0.93035480 - Test F1 Score: 0.91709845
# Epoch 83/250 - Time: 130.5217s - Training loss: 0.50833508 - Test Loss: 0.54913151 - Test Accuracy: 0.90666667 - Test Precision: 0.89353612 - Test Recall: 0.92641261 - Test F1 Score: 0.90967742
# Epoch 84/250 - Time: 127.7740s - Training loss: 0.50796104 - Test Loss: 0.53931714 - Test Accuracy: 0.91800000 - Test Precision: 0.92533333 - Test Recall: 0.91195795 - Test F1 Score: 0.91859696
# Epoch 85/250 - Time: 126.3216s - Training loss: 0.50955066 - Test Loss: 0.55002001 - Test Accuracy: 0.90866667 - Test Precision: 0.88329238 - Test Recall: 0.94480946 - Test F1 Score: 0.91301587
# Epoch 86/250 - Time: 126.2795s - Training loss: 0.51019389 - Test Loss: 0.54296674 - Test Accuracy: 0.89800000 - Test Precision: 0.95645646 - Test Recall: 0.83705650 - Test F1 Score: 0.89278206
# Epoch 87/250 - Time: 126.2258s - Training loss: 0.51052328 - Test Loss: 0.54281277 - Test Accuracy: 0.91600000 - Test Precision: 0.91180285 - Test Recall: 0.92378449 - Test F1 Score: 0.91775457
# Epoch 88/250 - Time: 126.2959s - Training loss: 0.50835055 - Test Loss: 0.54398237 - Test Accuracy: 0.91666667 - Test Precision: 0.90151515 - Test Recall: 0.93823916 - Test F1 Score: 0.91951062
# Epoch 89/250 - Time: 126.2036s - Training loss: 0.50816794 - Test Loss: 0.54041017 - Test Accuracy: 0.92200000 - Test Precision: 0.91709845 - Test Recall: 0.93035480 - Test F1 Score: 0.92367906
# Epoch 90/250 - Time: 126.2942s - Training loss: 0.50918783 - Test Loss: 0.54068147 - Test Accuracy: 0.91533333 - Test Precision: 0.93070652 - Test Recall: 0.90013141 - Test F1 Score: 0.91516366
# Epoch 91/250 - Time: 126.1702s - Training loss: 0.50869865 - Test Loss: 0.55066296 - Test Accuracy: 0.90200000 - Test Precision: 0.88959391 - Test Recall: 0.92115637 - Test F1 Score: 0.90510006
# Epoch 92/250 - Time: 126.1478s - Training loss: 0.50921908 - Test Loss: 0.54355887 - Test Accuracy: 0.91733333 - Test Precision: 0.90781050 - Test Recall: 0.93166886 - Test F1 Score: 0.91958495
# Epoch 93/250 - Time: 126.1280s - Training loss: 0.50907941 - Test Loss: 0.54906541 - Test Accuracy: 0.91133333 - Test Precision: 0.88480392 - Test Recall: 0.94875164 - Test F1 Score: 0.91566265
# Epoch 94/250 - Time: 126.1708s - Training loss: 0.50907428 - Test Loss: 0.54424130 - Test Accuracy: 0.91466667 - Test Precision: 0.91050584 - Test Recall: 0.92247043 - Test F1 Score: 0.91644909
# Epoch 95/250 - Time: 126.1800s - Training loss: 0.50946156 - Test Loss: 0.53949474 - Test Accuracy: 0.91266667 - Test Precision: 0.94617564 - Test Recall: 0.87779238 - Test F1 Score: 0.91070211
# Epoch 96/250 - Time: 126.1895s - Training loss: 0.50885916 - Test Loss: 0.53832662 - Test Accuracy: 0.91866667 - Test Precision: 0.94068966 - Test Recall: 0.89618922 - Test F1 Score: 0.91790040
# Epoch 97/250 - Time: 126.2096s - Training loss: 0.50801755 - Test Loss: 0.54164246 - Test Accuracy: 0.91800000 - Test Precision: 0.91536458 - Test Recall: 0.92378449 - Test F1 Score: 0.91955526
# Epoch 98/250 - Time: 126.1588s - Training loss: 0.50900091 - Test Loss: 0.54653358 - Test Accuracy: 0.91066667 - Test Precision: 0.90451613 - Test Recall: 0.92115637 - Test F1 Score: 0.91276042
# Epoch 99/250 - Time: 126.2706s - Training loss: 0.50966965 - Test Loss: 0.54566296 - Test Accuracy: 0.90333333 - Test Precision: 0.92307692 - Test Recall: 0.88304862 - Test F1 Score: 0.90261921
# Epoch 100/250 - Time: 126.1263s - Training loss: 0.51029490 - Test Loss: 0.54484307 - Test Accuracy: 0.89733333 - Test Precision: 0.95096582 - Test Recall: 0.84099869 - Test F1 Score: 0.89260809
# Epoch 101/250 - Time: 126.2085s - Training loss: 0.51099302 - Test Loss: 0.55914780 - Test Accuracy: 0.89666667 - Test Precision: 0.85731132 - Test Recall: 0.95532194 - Test F1 Score: 0.90366687
# Epoch 102/250 - Time: 126.1328s - Training loss: 0.50934099 - Test Loss: 0.54109072 - Test Accuracy: 0.91866667 - Test Precision: 0.91984231 - Test Recall: 0.91984231 - Test F1 Score: 0.91984231
# Epoch 103/250 - Time: 126.2446s - Training loss: 0.50770762 - Test Loss: 0.53834294 - Test Accuracy: 0.91933333 - Test Precision: 0.93478261 - Test Recall: 0.90407359 - Test F1 Score: 0.91917168
# Epoch 104/250 - Time: 126.1657s - Training loss: 0.50878895 - Test Loss: 0.54306951 - Test Accuracy: 0.90800000 - Test Precision: 0.92965517 - Test Recall: 0.88567674 - Test F1 Score: 0.90713324
# Epoch 105/250 - Time: 126.1990s - Training loss: 0.50835455 - Test Loss: 0.54563646 - Test Accuracy: 0.89266667 - Test Precision: 0.94910180 - Test Recall: 0.83311432 - Test F1 Score: 0.88733380
# Epoch 106/250 - Time: 126.0477s - Training loss: 0.50942630 - Test Loss: 0.54727865 - Test Accuracy: 0.91200000 - Test Precision: 0.89460477 - Test Recall: 0.93692510 - Test F1 Score: 0.91527599
# Epoch 107/250 - Time: 126.1219s - Training loss: 0.50827715 - Test Loss: 0.54264751 - Test Accuracy: 0.91866667 - Test Precision: 0.91014121 - Test Recall: 0.93166886 - Test F1 Score: 0.92077922
# Epoch 108/250 - Time: 126.0952s - Training loss: 0.50801942 - Test Loss: 0.54415643 - Test Accuracy: 0.91533333 - Test Precision: 0.90228426 - Test Recall: 0.93429698 - Test F1 Score: 0.91801162
# Epoch 109/250 - Time: 126.0904s - Training loss: 0.50727823 - Test Loss: 0.54454886 - Test Accuracy: 0.91333333 - Test Precision: 0.90815006 - Test Recall: 0.92247043 - Test F1 Score: 0.91525424
# Epoch 110/250 - Time: 126.1042s - Training loss: 0.50942323 - Test Loss: 0.54586434 - Test Accuracy: 0.90866667 - Test Precision: 0.91160950 - Test Recall: 0.90801577 - Test F1 Score: 0.90980908
# Epoch 111/250 - Time: 126.0688s - Training loss: 0.51294072 - Test Loss: 0.55153542 - Test Accuracy: 0.90866667 - Test Precision: 0.87231504 - Test Recall: 0.96057819 - Test F1 Score: 0.91432145
# Epoch 112/250 - Time: 126.1040s - Training loss: 0.50874689 - Test Loss: 0.54288512 - Test Accuracy: 0.90600000 - Test Precision: 0.93296089 - Test Recall: 0.87779238 - Test F1 Score: 0.90453622
# Epoch 113/250 - Time: 126.0337s - Training loss: 0.50764162 - Test Loss: 0.54460396 - Test Accuracy: 0.91400000 - Test Precision: 0.90932642 - Test Recall: 0.92247043 - Test F1 Score: 0.91585127
# Epoch 114/250 - Time: 126.0318s - Training loss: 0.50871456 - Test Loss: 0.53886512 - Test Accuracy: 0.92666667 - Test Precision: 0.91570881 - Test Recall: 0.94218134 - Test F1 Score: 0.92875648
# Epoch 115/250 - Time: 126.0677s - Training loss: 0.50736371 - Test Loss: 0.54353711 - Test Accuracy: 0.91733333 - Test Precision: 0.90676884 - Test Recall: 0.93298292 - Test F1 Score: 0.91968912
# Epoch 116/250 - Time: 126.1428s - Training loss: 0.50831382 - Test Loss: 0.54285824 - Test Accuracy: 0.92066667 - Test Precision: 0.90125000 - Test Recall: 0.94743758 - Test F1 Score: 0.92376682
# Epoch 117/250 - Time: 126.1989s - Training loss: 0.50724513 - Test Loss: 0.53842949 - Test Accuracy: 0.92400000 - Test Precision: 0.92734478 - Test Recall: 0.92247043 - Test F1 Score: 0.92490119
# Epoch 118/250 - Time: 126.1499s - Training loss: 0.50868444 - Test Loss: 0.53933620 - Test Accuracy: 0.91933333 - Test Precision: 0.93243243 - Test Recall: 0.90670171 - Test F1 Score: 0.91938708
# Epoch 119/250 - Time: 126.1624s - Training loss: 0.50841774 - Test Loss: 0.54104680 - Test Accuracy: 0.91733333 - Test Precision: 0.92185430 - Test Recall: 0.91458607 - Test F1 Score: 0.91820580
# Epoch 120/250 - Time: 126.1495s - Training loss: 0.50825692 - Test Loss: 0.54712709 - Test Accuracy: 0.91466667 - Test Precision: 0.89513109 - Test Recall: 0.94218134 - Test F1 Score: 0.91805378
# Epoch 121/250 - Time: 126.2502s - Training loss: 0.50849981 - Test Loss: 0.53946923 - Test Accuracy: 0.92333333 - Test Precision: 0.91948052 - Test Recall: 0.93035480 - Test F1 Score: 0.92488570
# Epoch 122/250 - Time: 126.1377s - Training loss: 0.50825637 - Test Loss: 0.54119926 - Test Accuracy: 0.91866667 - Test Precision: 0.91984231 - Test Recall: 0.91984231 - Test F1 Score: 0.91984231
# Epoch 123/250 - Time: 126.1196s - Training loss: 0.50734609 - Test Loss: 0.53972353 - Test Accuracy: 0.91666667 - Test Precision: 0.92857143 - Test Recall: 0.90538765 - Test F1 Score: 0.91683300
# Epoch 124/250 - Time: 126.1710s - Training loss: 0.50709738 - Test Loss: 0.53914671 - Test Accuracy: 0.91533333 - Test Precision: 0.93905817 - Test Recall: 0.89093298 - Test F1 Score: 0.91436278
# Epoch 125/250 - Time: 127.1750s - Training loss: 0.50798287 - Test Loss: 0.54910205 - Test Accuracy: 0.89000000 - Test Precision: 0.93440233 - Test Recall: 0.84231275 - Test F1 Score: 0.88597097
# Epoch 126/250 - Time: 130.3901s - Training loss: 0.50843044 - Test Loss: 0.54500680 - Test Accuracy: 0.91400000 - Test Precision: 0.90306122 - Test Recall: 0.93035480 - Test F1 Score: 0.91650485
# Epoch 127/250 - Time: 130.2976s - Training loss: 0.50749784 - Test Loss: 0.55574217 - Test Accuracy: 0.90466667 - Test Precision: 0.85930233 - Test Recall: 0.97109067 - Test F1 Score: 0.91178285
# Epoch 128/250 - Time: 130.4234s - Training loss: 0.50828766 - Test Loss: 0.54202722 - Test Accuracy: 0.91733333 - Test Precision: 0.91309987 - Test Recall: 0.92509855 - Test F1 Score: 0.91906005
# Epoch 129/250 - Time: 127.3623s - Training loss: 0.50713399 - Test Loss: 0.54183258 - Test Accuracy: 0.91200000 - Test Precision: 0.93023256 - Test Recall: 0.89356110 - Test F1 Score: 0.91152815
# Epoch 130/250 - Time: 126.0421s - Training loss: 0.50794462 - Test Loss: 0.53748813 - Test Accuracy: 0.92800000 - Test Precision: 0.92457737 - Test Recall: 0.93429698 - Test F1 Score: 0.92941176
# Epoch 131/250 - Time: 126.1816s - Training loss: 0.50895185 - Test Loss: 0.54165732 - Test Accuracy: 0.92533333 - Test Precision: 0.90111248 - Test Recall: 0.95795007 - Test F1 Score: 0.92866242
# Epoch 132/250 - Time: 126.0310s - Training loss: 0.50811991 - Test Loss: 0.54299279 - Test Accuracy: 0.91266667 - Test Precision: 0.91447368 - Test Recall: 0.91327201 - Test F1 Score: 0.91387245
# Epoch 133/250 - Time: 126.0187s - Training loss: 0.50811174 - Test Loss: 0.54020354 - Test Accuracy: 0.91933333 - Test Precision: 0.92666667 - Test Recall: 0.91327201 - Test F1 Score: 0.91992058
# Epoch 134/250 - Time: 125.9366s - Training loss: 0.50808201 - Test Loss: 0.54408177 - Test Accuracy: 0.90933333 - Test Precision: 0.91946309 - Test Recall: 0.90013141 - Test F1 Score: 0.90969456
# Epoch 135/250 - Time: 126.0378s - Training loss: 0.50872634 - Test Loss: 0.54308621 - Test Accuracy: 0.91533333 - Test Precision: 0.91383812 - Test Recall: 0.91984231 - Test F1 Score: 0.91683039
# Epoch 136/250 - Time: 126.0083s - Training loss: 0.50799285 - Test Loss: 0.53940097 - Test Accuracy: 0.91533333 - Test Precision: 0.94027778 - Test Recall: 0.88961892 - Test F1 Score: 0.91424713
# Epoch 137/250 - Time: 125.9668s - Training loss: 0.50707737 - Test Loss: 0.54571714 - Test Accuracy: 0.91333333 - Test Precision: 0.89987326 - Test Recall: 0.93298292 - Test F1 Score: 0.91612903
# Epoch 138/250 - Time: 126.0843s - Training loss: 0.50725415 - Test Loss: 0.54863625 - Test Accuracy: 0.90866667 - Test Precision: 0.89000000 - Test Recall: 0.93561104 - Test F1 Score: 0.91223575
# Epoch 139/250 - Time: 125.9768s - Training loss: 0.50807916 - Test Loss: 0.54388663 - Test Accuracy: 0.91866667 - Test Precision: 0.89987484 - Test Recall: 0.94480946 - Test F1 Score: 0.92179487
# Epoch 140/250 - Time: 126.0406s - Training loss: 0.50745502 - Test Loss: 0.53962491 - Test Accuracy: 0.92200000 - Test Precision: 0.92146597 - Test Recall: 0.92509855 - Test F1 Score: 0.92327869
# Epoch 141/250 - Time: 126.1953s - Training loss: 0.50696855 - Test Loss: 0.54225009 - Test Accuracy: 0.92200000 - Test Precision: 0.90350877 - Test Recall: 0.94743758 - Test F1 Score: 0.92495189
# Epoch 142/250 - Time: 126.0003s - Training loss: 0.50637159 - Test Loss: 0.53718883 - Test Accuracy: 0.91733333 - Test Precision: 0.94922426 - Test Recall: 0.88436268 - Test F1 Score: 0.91564626
# Epoch 143/250 - Time: 126.0739s - Training loss: 0.50777514 - Test Loss: 0.54228760 - Test Accuracy: 0.91800000 - Test Precision: 0.91214470 - Test Recall: 0.92772668 - Test F1 Score: 0.91986971
# Epoch 144/250 - Time: 126.0933s - Training loss: 0.50716268 - Test Loss: 0.53965874 - Test Accuracy: 0.92133333 - Test Precision: 0.92247043 - Test Recall: 0.92247043 - Test F1 Score: 0.92247043
# Epoch 145/250 - Time: 126.0492s - Training loss: 0.50799261 - Test Loss: 0.54624724 - Test Accuracy: 0.91200000 - Test Precision: 0.90063694 - Test Recall: 0.92904074 - Test F1 Score: 0.91461837
# Epoch 146/250 - Time: 126.0852s - Training loss: 0.50954047 - Test Loss: 0.54864041 - Test Accuracy: 0.91266667 - Test Precision: 0.88508557 - Test Recall: 0.95137976 - Test F1 Score: 0.91703610
# Epoch 147/250 - Time: 126.0250s - Training loss: 0.50755730 - Test Loss: 0.55592711 - Test Accuracy: 0.90200000 - Test Precision: 0.86202830 - Test Recall: 0.96057819 - Test F1 Score: 0.90863891
# Epoch 148/250 - Time: 125.9368s - Training loss: 0.50919865 - Test Loss: 0.54480032 - Test Accuracy: 0.91200000 - Test Precision: 0.91003911 - Test Recall: 0.91721419 - Test F1 Score: 0.91361257
# Epoch 149/250 - Time: 125.9469s - Training loss: 0.50935041 - Test Loss: 0.54039960 - Test Accuracy: 0.92466667 - Test Precision: 0.90909091 - Test Recall: 0.94612352 - Test F1 Score: 0.92723760
# Epoch 150/250 - Time: 126.1300s - Training loss: 0.50694022 - Test Loss: 0.53842245 - Test Accuracy: 0.92333333 - Test Precision: 0.92500000 - Test Recall: 0.92378449 - Test F1 Score: 0.92439185
# Epoch 151/250 - Time: 126.2530s - Training loss: 0.50717899 - Test Loss: 0.54095543 - Test Accuracy: 0.92000000 - Test Precision: 0.91461837 - Test Recall: 0.92904074 - Test F1 Score: 0.92177314
# Epoch 152/250 - Time: 126.0773s - Training loss: 0.50713276 - Test Loss: 0.55978632 - Test Accuracy: 0.89400000 - Test Precision: 0.85748219 - Test Recall: 0.94875164 - Test F1 Score: 0.90081098
# Epoch 153/250 - Time: 126.1199s - Training loss: 0.50842217 - Test Loss: 0.54375024 - Test Accuracy: 0.91333333 - Test Precision: 0.91458607 - Test Recall: 0.91458607 - Test F1 Score: 0.91458607
# Epoch 154/250 - Time: 126.2042s - Training loss: 0.50755876 - Test Loss: 0.54394947 - Test Accuracy: 0.91533333 - Test Precision: 0.90641026 - Test Recall: 0.92904074 - Test F1 Score: 0.91758598
# Epoch 155/250 - Time: 126.0389s - Training loss: 0.50719251 - Test Loss: 0.54456483 - Test Accuracy: 0.91666667 - Test Precision: 0.89949749 - Test Recall: 0.94086728 - Test F1 Score: 0.91971741
# Epoch 156/250 - Time: 126.1285s - Training loss: 0.50856647 - Test Loss: 0.54300169 - Test Accuracy: 0.90800000 - Test Precision: 0.92847318 - Test Recall: 0.88699080 - Test F1 Score: 0.90725806
# Epoch 157/250 - Time: 126.1048s - Training loss: 0.50925772 - Test Loss: 0.54246193 - Test Accuracy: 0.91000000 - Test Precision: 0.93112948 - Test Recall: 0.88830486 - Test F1 Score: 0.90921318
# Epoch 158/250 - Time: 126.0348s - Training loss: 0.50685490 - Test Loss: 0.54043421 - Test Accuracy: 0.91933333 - Test Precision: 0.92216359 - Test Recall: 0.91852825 - Test F1 Score: 0.92034233
# Epoch 159/250 - Time: 126.1371s - Training loss: 0.50652610 - Test Loss: 0.53943500 - Test Accuracy: 0.92133333 - Test Precision: 0.92358366 - Test Recall: 0.92115637 - Test F1 Score: 0.92236842
# Epoch 160/250 - Time: 126.0389s - Training loss: 0.50667904 - Test Loss: 0.53979631 - Test Accuracy: 0.91666667 - Test Precision: 0.93206522 - Test Recall: 0.90144547 - Test F1 Score: 0.91649967
# Epoch 161/250 - Time: 126.1065s - Training loss: 0.50641112 - Test Loss: 0.53895554 - Test Accuracy: 0.92600000 - Test Precision: 0.91560102 - Test Recall: 0.94086728 - Test F1 Score: 0.92806222
# Epoch 162/250 - Time: 126.0416s - Training loss: 0.50609742 - Test Loss: 0.53760136 - Test Accuracy: 0.92466667 - Test Precision: 0.92970822 - Test Recall: 0.92115637 - Test F1 Score: 0.92541254
# Epoch 163/250 - Time: 126.0272s - Training loss: 0.50662766 - Test Loss: 0.54978917 - Test Accuracy: 0.91133333 - Test Precision: 0.87922705 - Test Recall: 0.95663601 - Test F1 Score: 0.91629956
# Epoch 164/250 - Time: 126.0908s - Training loss: 0.50859676 - Test Loss: 0.53916753 - Test Accuracy: 0.92133333 - Test Precision: 0.92582781 - Test Recall: 0.91852825 - Test F1 Score: 0.92216359
# Epoch 165/250 - Time: 126.0316s - Training loss: 0.50671490 - Test Loss: 0.53934920 - Test Accuracy: 0.91733333 - Test Precision: 0.93333333 - Test Recall: 0.90144547 - Test F1 Score: 0.91711230
# Epoch 166/250 - Time: 126.0943s - Training loss: 0.50915546 - Test Loss: 0.54314741 - Test Accuracy: 0.91400000 - Test Precision: 0.91578947 - Test Recall: 0.91458607 - Test F1 Score: 0.91518738
# Epoch 167/250 - Time: 126.0725s - Training loss: 0.50962514 - Test Loss: 0.54240448 - Test Accuracy: 0.91600000 - Test Precision: 0.91612058 - Test Recall: 0.91852825 - Test F1 Score: 0.91732283
# Epoch 168/250 - Time: 125.9341s - Training loss: 0.50797861 - Test Loss: 0.55638576 - Test Accuracy: 0.90200000 - Test Precision: 0.86117647 - Test Recall: 0.96189225 - Test F1 Score: 0.90875233
# Epoch 169/250 - Time: 126.0654s - Training loss: 0.50755846 - Test Loss: 0.54590695 - Test Accuracy: 0.91133333 - Test Precision: 0.90359897 - Test Recall: 0.92378449 - Test F1 Score: 0.91358025
# Epoch 170/250 - Time: 126.0826s - Training loss: 0.50829189 - Test Loss: 0.53882386 - Test Accuracy: 0.92066667 - Test Precision: 0.93145161 - Test Recall: 0.91064389 - Test F1 Score: 0.92093023
# Epoch 171/250 - Time: 126.0415s - Training loss: 0.50749210 - Test Loss: 0.54182537 - Test Accuracy: 0.91533333 - Test Precision: 0.92154255 - Test Recall: 0.91064389 - Test F1 Score: 0.91606081
# Epoch 172/250 - Time: 126.0036s - Training loss: 0.50817105 - Test Loss: 0.54090087 - Test Accuracy: 0.92133333 - Test Precision: 0.91483871 - Test Recall: 0.93166886 - Test F1 Score: 0.92317708
# Epoch 173/250 - Time: 126.2122s - Training loss: 0.50699158 - Test Loss: 0.54075555 - Test Accuracy: 0.92133333 - Test Precision: 0.91060026 - Test Recall: 0.93692510 - Test F1 Score: 0.92357513
# Epoch 174/250 - Time: 126.0363s - Training loss: 0.50740118 - Test Loss: 0.53964155 - Test Accuracy: 0.92266667 - Test Precision: 0.91937581 - Test Recall: 0.92904074 - Test F1 Score: 0.92418301
# Epoch 175/250 - Time: 126.0123s - Training loss: 0.50741215 - Test Loss: 0.54114117 - Test Accuracy: 0.91400000 - Test Precision: 0.92934783 - Test Recall: 0.89881735 - Test F1 Score: 0.91382766
# Epoch 176/250 - Time: 126.0187s - Training loss: 0.50724747 - Test Loss: 0.54250828 - Test Accuracy: 0.92000000 - Test Precision: 0.90724269 - Test Recall: 0.93823916 - Test F1 Score: 0.92248062
# Epoch 177/250 - Time: 125.9852s - Training loss: 0.50681922 - Test Loss: 0.56179022 - Test Accuracy: 0.89266667 - Test Precision: 0.85211268 - Test Recall: 0.95400788 - Test F1 Score: 0.90018599
# Epoch 178/250 - Time: 126.1034s - Training loss: 0.50810497 - Test Loss: 0.54482053 - Test Accuracy: 0.91200000 - Test Precision: 0.90897269 - Test Recall: 0.91852825 - Test F1 Score: 0.91372549
# Epoch 179/250 - Time: 126.0423s - Training loss: 0.50781058 - Test Loss: 0.54284856 - Test Accuracy: 0.91733333 - Test Precision: 0.91203105 - Test Recall: 0.92641261 - Test F1 Score: 0.91916558
# Epoch 180/250 - Time: 126.0943s - Training loss: 0.50847654 - Test Loss: 0.55221128 - Test Accuracy: 0.90733333 - Test Precision: 0.87469880 - Test Recall: 0.95400788 - Test F1 Score: 0.91263356
# Epoch 181/250 - Time: 126.1273s - Training loss: 0.50810786 - Test Loss: 0.53742794 - Test Accuracy: 0.92066667 - Test Precision: 0.94459834 - Test Recall: 0.89618922 - Test F1 Score: 0.91975725
# Epoch 182/250 - Time: 126.0679s - Training loss: 0.50683477 - Test Loss: 0.54326344 - Test Accuracy: 0.91600000 - Test Precision: 0.91073739 - Test Recall: 0.92509855 - Test F1 Score: 0.91786180
# Epoch 183/250 - Time: 126.0446s - Training loss: 0.50695771 - Test Loss: 0.54519400 - Test Accuracy: 0.91733333 - Test Precision: 0.89862328 - Test Recall: 0.94349540 - Test F1 Score: 0.92051282
# Epoch 184/250 - Time: 126.1393s - Training loss: 0.50769353 - Test Loss: 0.54083041 - Test Accuracy: 0.91800000 - Test Precision: 0.91863517 - Test Recall: 0.91984231 - Test F1 Score: 0.91923835
# Epoch 185/250 - Time: 126.1375s - Training loss: 0.50721428 - Test Loss: 0.54498240 - Test Accuracy: 0.91200000 - Test Precision: 0.90897269 - Test Recall: 0.91852825 - Test F1 Score: 0.91372549
# Epoch 186/250 - Time: 126.0623s - Training loss: 0.50728527 - Test Loss: 0.54545210 - Test Accuracy: 0.91533333 - Test Precision: 0.89724311 - Test Recall: 0.94086728 - Test F1 Score: 0.91853752
# Epoch 187/250 - Time: 126.0594s - Training loss: 0.50716973 - Test Loss: 0.54465715 - Test Accuracy: 0.91800000 - Test Precision: 0.89875000 - Test Recall: 0.94480946 - Test F1 Score: 0.92120436
# Epoch 188/250 - Time: 125.9980s - Training loss: 0.50700112 - Test Loss: 0.53899782 - Test Accuracy: 0.92800000 - Test Precision: 0.91276865 - Test Recall: 0.94875164 - Test F1 Score: 0.93041237
# Epoch 189/250 - Time: 126.0611s - Training loss: 0.50613700 - Test Loss: 0.53537037 - Test Accuracy: 0.93333333 - Test Precision: 0.92535393 - Test Recall: 0.94480946 - Test F1 Score: 0.93498049
# Epoch 190/250 - Time: 126.0219s - Training loss: 0.50694162 - Test Loss: 0.53976851 - Test Accuracy: 0.92266667 - Test Precision: 0.92156863 - Test Recall: 0.92641261 - Test F1 Score: 0.92398427
# Epoch 191/250 - Time: 125.9787s - Training loss: 0.50866263 - Test Loss: 0.54306283 - Test Accuracy: 0.91666667 - Test Precision: 0.91085271 - Test Recall: 0.92641261 - Test F1 Score: 0.91856678
# Epoch 192/250 - Time: 126.1089s - Training loss: 0.50696660 - Test Loss: 0.53894991 - Test Accuracy: 0.92400000 - Test Precision: 0.92177314 - Test Recall: 0.92904074 - Test F1 Score: 0.92539267
# Epoch 193/250 - Time: 126.0345s - Training loss: 0.50873800 - Test Loss: 0.54397564 - Test Accuracy: 0.90066667 - Test Precision: 0.94347826 - Test Recall: 0.85545335 - Test F1 Score: 0.89731220
# Epoch 194/250 - Time: 126.0333s - Training loss: 0.50839347 - Test Loss: 0.54154606 - Test Accuracy: 0.91400000 - Test Precision: 0.92702703 - Test Recall: 0.90144547 - Test F1 Score: 0.91405730
# Epoch 195/250 - Time: 125.9777s - Training loss: 0.50803857 - Test Loss: 0.54339180 - Test Accuracy: 0.90866667 - Test Precision: 0.92857143 - Test Recall: 0.88830486 - Test F1 Score: 0.90799194
# Epoch 196/250 - Time: 125.8514s - Training loss: 0.50660462 - Test Loss: 0.55059403 - Test Accuracy: 0.90733333 - Test Precision: 0.87926829 - Test Recall: 0.94743758 - Test F1 Score: 0.91208096
# Epoch 197/250 - Time: 126.0056s - Training loss: 0.50699493 - Test Loss: 0.54414092 - Test Accuracy: 0.91733333 - Test Precision: 0.90265487 - Test Recall: 0.93823916 - Test F1 Score: 0.92010309
# Epoch 198/250 - Time: 125.9699s - Training loss: 0.50671820 - Test Loss: 0.54329705 - Test Accuracy: 0.91800000 - Test Precision: 0.90075377 - Test Recall: 0.94218134 - Test F1 Score: 0.92100193
# Epoch 199/250 - Time: 125.9454s - Training loss: 0.51060144 - Test Loss: 0.54701641 - Test Accuracy: 0.90733333 - Test Precision: 0.91029024 - Test Recall: 0.90670171 - Test F1 Score: 0.90849243
# Epoch 200/250 - Time: 125.9962s - Training loss: 0.50932339 - Test Loss: 0.53934173 - Test Accuracy: 0.91800000 - Test Precision: 0.93342391 - Test Recall: 0.90275953 - Test F1 Score: 0.91783567
# Epoch 201/250 - Time: 126.0246s - Training loss: 0.50767922 - Test Loss: 0.53751250 - Test Accuracy: 0.92533333 - Test Precision: 0.92753623 - Test Recall: 0.92509855 - Test F1 Score: 0.92631579
# Epoch 202/250 - Time: 125.9984s - Training loss: 0.50809482 - Test Loss: 0.53818504 - Test Accuracy: 0.92000000 - Test Precision: 0.93605442 - Test Recall: 0.90407359 - Test F1 Score: 0.91978610
# Epoch 203/250 - Time: 126.0185s - Training loss: 0.50706866 - Test Loss: 0.54903088 - Test Accuracy: 0.91000000 - Test Precision: 0.88641975 - Test Recall: 0.94349540 - Test F1 Score: 0.91406747
# Epoch 204/250 - Time: 126.1100s - Training loss: 0.50634684 - Test Loss: 0.54251419 - Test Accuracy: 0.91600000 - Test Precision: 0.91503268 - Test Recall: 0.91984231 - Test F1 Score: 0.91743119
# Epoch 205/250 - Time: 126.0450s - Training loss: 0.50758709 - Test Loss: 0.54405465 - Test Accuracy: 0.91400000 - Test Precision: 0.91253264 - Test Recall: 0.91852825 - Test F1 Score: 0.91552063
# Epoch 206/250 - Time: 126.0627s - Training loss: 0.50807156 - Test Loss: 0.54206217 - Test Accuracy: 0.91533333 - Test Precision: 0.92042440 - Test Recall: 0.91195795 - Test F1 Score: 0.91617162
# Epoch 207/250 - Time: 125.9512s - Training loss: 0.50677214 - Test Loss: 0.55024365 - Test Accuracy: 0.91000000 - Test Precision: 0.87620192 - Test Recall: 0.95795007 - Test F1 Score: 0.91525424
# Epoch 208/250 - Time: 125.9696s - Training loss: 0.50839363 - Test Loss: 0.54458556 - Test Accuracy: 0.91133333 - Test Precision: 0.91207349 - Test Recall: 0.91327201 - Test F1 Score: 0.91267236
# Epoch 209/250 - Time: 126.0880s - Training loss: 0.50629916 - Test Loss: 0.53654413 - Test Accuracy: 0.92733333 - Test Precision: 0.93121693 - Test Recall: 0.92509855 - Test F1 Score: 0.92814766
# Epoch 210/250 - Time: 126.0652s - Training loss: 0.50640983 - Test Loss: 0.53846902 - Test Accuracy: 0.92533333 - Test Precision: 0.92088197 - Test Recall: 0.93298292 - Test F1 Score: 0.92689295
# Epoch 211/250 - Time: 125.9919s - Training loss: 0.50593474 - Test Loss: 0.54019807 - Test Accuracy: 0.91933333 - Test Precision: 0.92216359 - Test Recall: 0.91852825 - Test F1 Score: 0.92034233
# Epoch 212/250 - Time: 125.9288s - Training loss: 0.50701445 - Test Loss: 0.54348384 - Test Accuracy: 0.91666667 - Test Precision: 0.90769231 - Test Recall: 0.93035480 - Test F1 Score: 0.91888384
# Epoch 213/250 - Time: 125.9332s - Training loss: 0.50785625 - Test Loss: 0.54438034 - Test Accuracy: 0.91666667 - Test Precision: 0.89949749 - Test Recall: 0.94086728 - Test F1 Score: 0.91971741
# Epoch 214/250 - Time: 126.0323s - Training loss: 0.50634675 - Test Loss: 0.53986594 - Test Accuracy: 0.92266667 - Test Precision: 0.92046936 - Test Recall: 0.92772668 - Test F1 Score: 0.92408377
# Epoch 215/250 - Time: 125.9233s - Training loss: 0.50605876 - Test Loss: 0.54116919 - Test Accuracy: 0.91733333 - Test Precision: 0.92297477 - Test Recall: 0.91327201 - Test F1 Score: 0.91809775
# Epoch 216/250 - Time: 126.0009s - Training loss: 0.50596013 - Test Loss: 0.54078176 - Test Accuracy: 0.92333333 - Test Precision: 0.91094148 - Test Recall: 0.94086728 - Test F1 Score: 0.92566257
# Epoch 217/250 - Time: 126.0884s - Training loss: 0.50867444 - Test Loss: 0.53960151 - Test Accuracy: 0.91666667 - Test Precision: 0.93442623 - Test Recall: 0.89881735 - Test F1 Score: 0.91627595
# Epoch 218/250 - Time: 126.0272s - Training loss: 0.50708280 - Test Loss: 0.54215464 - Test Accuracy: 0.91600000 - Test Precision: 0.91831357 - Test Recall: 0.91590013 - Test F1 Score: 0.91710526
# Epoch 219/250 - Time: 125.9268s - Training loss: 0.50899075 - Test Loss: 0.54220745 - Test Accuracy: 0.91866667 - Test Precision: 0.91119691 - Test Recall: 0.93035480 - Test F1 Score: 0.92067620
# Epoch 220/250 - Time: 125.9489s - Training loss: 0.50688804 - Test Loss: 0.53958451 - Test Accuracy: 0.92000000 - Test Precision: 0.92676431 - Test Recall: 0.91458607 - Test F1 Score: 0.92063492
# Epoch 221/250 - Time: 125.9361s - Training loss: 0.50719837 - Test Loss: 0.54715387 - Test Accuracy: 0.91066667 - Test Precision: 0.89433962 - Test Recall: 0.93429698 - Test F1 Score: 0.91388175
# Epoch 222/250 - Time: 126.1005s - Training loss: 0.50637492 - Test Loss: 0.54246677 - Test Accuracy: 0.91666667 - Test Precision: 0.91406250 - Test Recall: 0.92247043 - Test F1 Score: 0.91824722
# Epoch 223/250 - Time: 126.0634s - Training loss: 0.50712500 - Test Loss: 0.53963503 - Test Accuracy: 0.92066667 - Test Precision: 0.92686170 - Test Recall: 0.91590013 - Test F1 Score: 0.92134831
# Epoch 224/250 - Time: 126.2407s - Training loss: 0.50735046 - Test Loss: 0.53970326 - Test Accuracy: 0.91933333 - Test Precision: 0.92666667 - Test Recall: 0.91327201 - Test F1 Score: 0.91992058
# Epoch 225/250 - Time: 126.1541s - Training loss: 0.50674727 - Test Loss: 0.56004525 - Test Accuracy: 0.89600000 - Test Precision: 0.85133566 - Test Recall: 0.96320631 - Test F1 Score: 0.90382244
# Epoch 226/250 - Time: 126.2275s - Training loss: 0.50836282 - Test Loss: 0.54029644 - Test Accuracy: 0.92000000 - Test Precision: 0.92115637 - Test Recall: 0.92115637 - Test F1 Score: 0.92115637
# Epoch 227/250 - Time: 126.1119s - Training loss: 0.50686292 - Test Loss: 0.54323676 - Test Accuracy: 0.91933333 - Test Precision: 0.90404040 - Test Recall: 0.94086728 - Test F1 Score: 0.92208628
# Epoch 228/250 - Time: 126.1823s - Training loss: 0.50872286 - Test Loss: 0.54381388 - Test Accuracy: 0.91000000 - Test Precision: 0.92183288 - Test Recall: 0.89881735 - Test F1 Score: 0.91017964
# Epoch 229/250 - Time: 126.1580s - Training loss: 0.50688665 - Test Loss: 0.53989268 - Test Accuracy: 0.92133333 - Test Precision: 0.92136304 - Test Recall: 0.92378449 - Test F1 Score: 0.92257218
# Epoch 230/250 - Time: 126.0341s - Training loss: 0.50645762 - Test Loss: 0.54237957 - Test Accuracy: 0.91733333 - Test Precision: 0.91743119 - Test Recall: 0.91984231 - Test F1 Score: 0.91863517
# Epoch 231/250 - Time: 126.1173s - Training loss: 0.50652148 - Test Loss: 0.54594838 - Test Accuracy: 0.91466667 - Test Precision: 0.89612015 - Test Recall: 0.94086728 - Test F1 Score: 0.91794872
# Epoch 232/250 - Time: 125.9279s - Training loss: 0.50725830 - Test Loss: 0.55056044 - Test Accuracy: 0.88533333 - Test Precision: 0.93629630 - Test Recall: 0.83048620 - Test F1 Score: 0.88022284
# Epoch 233/250 - Time: 126.0186s - Training loss: 0.50809063 - Test Loss: 0.54215127 - Test Accuracy: 0.91200000 - Test Precision: 0.92789116 - Test Recall: 0.89618922 - Test F1 Score: 0.91176471
# Epoch 234/250 - Time: 126.0229s - Training loss: 0.50662498 - Test Loss: 0.54234050 - Test Accuracy: 0.92000000 - Test Precision: 0.90724269 - Test Recall: 0.93823916 - Test F1 Score: 0.92248062
# Epoch 235/250 - Time: 126.1442s - Training loss: 0.50600338 - Test Loss: 0.53937612 - Test Accuracy: 0.91533333 - Test Precision: 0.94150418 - Test Recall: 0.88830486 - Test F1 Score: 0.91413117
# Epoch 236/250 - Time: 126.0507s - Training loss: 0.50595693 - Test Loss: 0.54038967 - Test Accuracy: 0.92000000 - Test Precision: 0.92005242 - Test Recall: 0.92247043 - Test F1 Score: 0.92125984
# Epoch 237/250 - Time: 126.0919s - Training loss: 0.50897667 - Test Loss: 0.56098559 - Test Accuracy: 0.86066667 - Test Precision: 0.92857143 - Test Recall: 0.78580815 - Test F1 Score: 0.85124555
# Epoch 238/250 - Time: 125.9643s - Training loss: 0.51031906 - Test Loss: 0.54439455 - Test Accuracy: 0.91533333 - Test Precision: 0.90228426 - Test Recall: 0.93429698 - Test F1 Score: 0.91801162
# Epoch 239/250 - Time: 126.0042s - Training loss: 0.50750555 - Test Loss: 0.54167137 - Test Accuracy: 0.91600000 - Test Precision: 0.92052980 - Test Recall: 0.91327201 - Test F1 Score: 0.91688654
# Epoch 240/250 - Time: 126.0594s - Training loss: 0.50638516 - Test Loss: 0.54301714 - Test Accuracy: 0.91400000 - Test Precision: 0.91578947 - Test Recall: 0.91458607 - Test F1 Score: 0.91518738
# Epoch 241/250 - Time: 126.1691s - Training loss: 0.50675679 - Test Loss: 0.54243767 - Test Accuracy: 0.91000000 - Test Precision: 0.93112948 - Test Recall: 0.88830486 - Test F1 Score: 0.90921318
# Epoch 242/250 - Time: 126.0487s - Training loss: 0.50654633 - Test Loss: 0.54400875 - Test Accuracy: 0.90666667 - Test Precision: 0.92709766 - Test Recall: 0.88567674 - Test F1 Score: 0.90591398
# Epoch 243/250 - Time: 126.0824s - Training loss: 0.50814582 - Test Loss: 0.54350376 - Test Accuracy: 0.90533333 - Test Precision: 0.93776521 - Test Recall: 0.87122208 - Test F1 Score: 0.90326975
# Epoch 244/250 - Time: 126.1690s - Training loss: 0.50715898 - Test Loss: 0.54090695 - Test Accuracy: 0.92000000 - Test Precision: 0.91569390 - Test Recall: 0.92772668 - Test F1 Score: 0.92167102
# Epoch 245/250 - Time: 126.2702s - Training loss: 0.50652754 - Test Loss: 0.54180261 - Test Accuracy: 0.91666667 - Test Precision: 0.92063492 - Test Recall: 0.91458607 - Test F1 Score: 0.91760053
# Epoch 246/250 - Time: 126.2327s - Training loss: 0.50678641 - Test Loss: 0.54571034 - Test Accuracy: 0.91800000 - Test Precision: 0.89578164 - Test Recall: 0.94875164 - Test F1 Score: 0.92150606
# Epoch 247/250 - Time: 126.0080s - Training loss: 0.50831644 - Test Loss: 0.54450794 - Test Accuracy: 0.91333333 - Test Precision: 0.90920882 - Test Recall: 0.92115637 - Test F1 Score: 0.91514360
# Epoch 248/250 - Time: 125.9521s - Training loss: 0.50748776 - Test Loss: 0.54012590 - Test Accuracy: 0.91866667 - Test Precision: 0.92885906 - Test Recall: 0.90932983 - Test F1 Score: 0.91899070
# Epoch 249/250 - Time: 126.0808s - Training loss: 0.50647202 - Test Loss: 0.54474194 - Test Accuracy: 0.91733333 - Test Precision: 0.89962359 - Test Recall: 0.94218134 - Test F1 Score: 0.92041078
# Epoch 250/250 - Time: 126.1352s - Training loss: 0.50685962 - Test Loss: 0.54257335 - Test Accuracy: 0.91400000 - Test Precision: 0.91798942 - Test Recall: 0.91195795 - Test F1 Score: 0.91496374
# Total Training Time: 31580.4090s
